# %%
import chromadb
from chromadb.utils import embedding_functions
from pathlib import Path

# Configuration
CHROMA_PATH = "./enhanced_embeddings"
COLLECTION_NAME = "research_paper_sections"
MODEL_NAME = "all-MiniLM-L6-v2"


def retrieve_all_chunks():
    """Retrieve and print all chunks with their metadata from ChromaDB."""
    
    print(f"Connecting to ChromaDB at: {CHROMA_PATH}")
    print("=" * 80)
    
    # Check if path exists
    if not Path(CHROMA_PATH).exists():
        print(f"❌ Error: ChromaDB path does not exist: {CHROMA_PATH}")
        return
    
    # Initialize client
    client = chromadb.PersistentClient(path=CHROMA_PATH)
    
    # Initialize embedding function
    try:
        embed_func = embedding_functions.SentenceTransformerEmbeddingFunction(
            model_name=MODEL_NAME
        )
    except Exception as e:
        print(f"Warning: Could not initialize SentenceTransformer: {e}")
        embed_func = None
    
    # Get the collection
    try:
        collection = client.get_collection(
            name=COLLECTION_NAME,
            embedding_function=embed_func
        )
    except Exception as e:
        print(f"❌ Error: Could not get collection '{COLLECTION_NAME}': {e}")
        print("\nAvailable collections:")
        for col in client.list_collections():
            print(f"  - {col.name}")
        return
    
    print(f"✅ Successfully connected to collection: '{COLLECTION_NAME}'")
    print(f"📊 Total documents in collection: {collection.count()}")
    print("=" * 80)
    
    # Get all data from the collection
    all_data = collection.get(
        include=['documents', 'metadatas', 'embeddings']
    )
    
    print(f"\n📋 Retrieved {len(all_data['ids'])} chunks\n")
    
    # Group by paper_id for better organization
    papers = {}
    for i, chunk_id in enumerate(all_data['ids']):
        metadata = all_data['metadatas'][i]
        document = all_data['documents'][i]
        
        paper_id = metadata.get('paper_id', 'Unknown')
        
        if paper_id not in papers:
            papers[paper_id] = []
        
        papers[paper_id].append({
            'id': chunk_id,
            'metadata': metadata,
            'document': document
        })
    
    # Print organized results
    for paper_id, chunks in papers.items():
        print("=" * 80)
        print(f"📄 PAPER: {paper_id}")
        print(f"   Total Chunks: {len(chunks)}")
        print("=" * 80)
        
        # Group by section
        sections = {}
        for chunk in chunks:
            section = chunk['metadata'].get('section_category', 'Unknown')
            if section not in sections:
                sections[section] = []
            sections[section].append(chunk)
        
        for section_name, section_chunks in sections.items():
            print(f"\n  📑 Section: {section_name}")
            print(f"     Chunks in this section: {len(section_chunks)}")
            print("     " + "-" * 70)
            
            for idx, chunk in enumerate(section_chunks, 1):
                metadata = chunk['metadata']
                doc_text = chunk['document']
                
                print(f"\n     Chunk {idx}:")
                print(f"       ID: {chunk['id']}")
                print(f"       Metadata: {metadata}")
                print(f"       Page Number: {metadata.get('page_number', 'N/A')}")
                print(f"       Chunk Number: {metadata.get('chunk_number', 'N/A')}")
                print(f"       Text Preview: {doc_text[:150]}...")
                print(f"       Text Length: {len(doc_text)} characters")
        
        print("\n")
    
    # Print summary statistics
    print("=" * 80)
    print("📊 SUMMARY STATISTICS")
    print("=" * 80)
    print(f"Total Papers: {len(papers)}")
    
    for paper_id, chunks in papers.items():
        sections = {}
        for chunk in chunks:
            section = chunk['metadata'].get('section_category', 'Unknown')
            sections[section] = sections.get(section, 0) + 1
        
        print(f"\n{paper_id}:")
        for section, count in sorted(sections.items()):
            print(f"  - {section}: {count} chunks")


def search_specific_section(paper_id: str, section_name: str):
    """Search for a specific paper and section."""
    
    print(f"\n🔍 Searching for: Paper={paper_id}, Section={section_name}")
    print("=" * 80)
    
    client = chromadb.PersistentClient(path=CHROMA_PATH)
    
    try:
        embed_func = embedding_functions.SentenceTransformerEmbeddingFunction(
            model_name=MODEL_NAME
        )
    except:
        embed_func = None
    
    collection = client.get_collection(
        name=COLLECTION_NAME,
        embedding_function=embed_func
    )
    
    # Query with filters
    results = collection.get(
        where={
            "$and": [
                {"paper_id": paper_id},
                {"section_category": section_name}
            ]
        },
        include=['documents', 'metadatas']
    )
    
    print(f"✅ Found {len(results['ids'])} chunks")
    print("=" * 80)
    
    for i, chunk_id in enumerate(results['ids'], 1):
        metadata = results['metadatas'][i-1]
        document = results['documents'][i-1]
        
        print(f"\nChunk {i}:")
        print(f"  ID: {chunk_id}")
        print(f"  Metadata: {metadata}")
        print(f"  Text Preview: {document[:200]}...")
        print("-" * 80)


retrieve_all_chunks()
# Out:
# Connecting to ChromaDB at: ./enhanced_embeddings
# ================================================================================
# ✅ Successfully connected to collection: 'research_paper_sections'
# 📊 Total documents in collection: 132
# ================================================================================
#
# 📋 Retrieved 132 chunks
#
# ================================================================================
# 📄 PAPER: 1
#    Total Chunks: 24
# ================================================================================
#
#   📑 Section: Introduction
#      Chunks in this section: 3
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-0-Introduction
#        Metadata: {'section_category': 'Introduction', 'page_number': 1, 'paper_id': 1, 'chunk_number': 0}
#        Page Number: 1
#        Chunk Number: 0
#        Text Preview: I. INTRODUCTION Writing the computer code necessary for software to run is known as software programming. The terms used in the ﬁeld of computer techn...
#        Text Length: 1248 characters
#
#      Chunk 2:
#        ID: paper-1-1-Introduction
#        Metadata: {'paper_id': 1, 'page_number': 1, 'section_category': 'Introduction', 'chunk_number': 1}
#        Page Number: 1
#        Chunk Number: 1
#        Text Preview: the entire ML Development Life Cycle, much as ”software development” or ”programming” is a minor component of the broader Software Development Life Cy...
#        Text Length: 1303 characters
#
#      Chunk 3:
#        ID: paper-1-2-Introduction
#        Metadata: {'page_number': 1, 'chunk_number': 2, 'section_category': 'Introduction', 'paper_id': 1}
#        Page Number: 1
#        Chunk Number: 2
#        Text Preview: Development Lifecycle and Machine Learning Development Lifecycle are examined, and then some key features of ML Development Lifecycle tools are discus...
#        Text Length: 1022 characters
#
#   📑 Section: Background
#      Chunks in this section: 5
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-3-Background
#        Metadata: {'section_category': 'Background', 'page_number': 2, 'paper_id': 1, 'chunk_number': 3}
#        Page Number: 2
#        Chunk Number: 3
#        Text Preview: II. BACKGROUND A. Software Development Lifecycle A typical software development life cycle has 6 stages: 1) Planning and Requirement Analysis The requ...
#        Text Length: 1335 characters
#
#      Chunk 2:
#        ID: paper-1-4-Background
#        Metadata: {'chunk_number': 4, 'paper_id': 1, 'section_category': 'Background', 'page_number': 2}
#        Page Number: 2
#        Chunk Number: 4
#        Text Preview: programming code is generated according to the According to Design Document Speciﬁcation (DDS). To create the code, developers employ programming tool...
#        Text Length: 1330 characters
#
#      Chunk 3:
#        ID: paper-1-5-Background
#        Metadata: {'paper_id': 1, 'page_number': 2, 'chunk_number': 5, 'section_category': 'Background'}
#        Page Number: 2
#        Chunk Number: 5
#        Text Preview: on the input data and the training process. The machine learning development lifecycle consists of the following steps: 1) Building the machine learni...
#        Text Length: 1317 characters
#
#      Chunk 4:
#        ID: paper-1-6-Background
#        Metadata: {'paper_id': 1, 'section_category': 'Background', 'chunk_number': 6, 'page_number': 2}
#        Page Number: 2
#        Chunk Number: 6
#        Text Preview: is utilized. The remaining data is then used to test the model. In order to enhance the model’s performance, these two phases are frequently repeated....
#        Text Length: 1301 characters
#
#      Chunk 5:
#        ID: paper-1-7-Background
#        Metadata: {'section_category': 'Background', 'page_number': 2, 'chunk_number': 7, 'paper_id': 1}
#        Page Number: 2
#        Chunk Number: 7
#        Text Preview: provides enough information for users to decide whether the model is suitable for the application for which it is designed. As a result, the emphasis ...
#        Text Length: 865 characters
#
#   📑 Section: Literature Review
#      Chunks in this section: 2
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-8-Literature_Review
#        Metadata: {'section_category': 'Literature Review', 'page_number': 3, 'chunk_number': 8, 'paper_id': 1}
#        Page Number: 3
#        Chunk Number: 8
#        Text Preview: III. LITERATURE REVIEW [1] and [2] discuss how the Microsoft and Google AI platform, Azure and Google Cloud, respectively, support deep learning and b...
#        Text Length: 1315 characters
#
#      Chunk 2:
#        ID: paper-1-9-Literature_Review
#        Metadata: {'chunk_number': 9, 'paper_id': 1, 'page_number': 3, 'section_category': 'Literature Review'}
#        Page Number: 3
#        Chunk Number: 9
#        Text Preview: the advantages, challenges and applications which can help outline the overall structure of ML development. The relationship between the stages of the...
#        Text Length: 988 characters
#
#   📑 Section: Key Features Of a Tool
#      Chunks in this section: 10
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-10-Key_Features_Of_a_Tool
#        Metadata: {'paper_id': 1, 'chunk_number': 10, 'page_number': 3, 'section_category': 'Key Features Of a Tool'}
#        Page Number: 3
#        Chunk Number: 10
#        Text Preview: IV. KEY FEATURES OF A TOOL Tool must support all the following activities: A. Data ingestion Data ingestion is the process of acquiring and importing ...
#        Text Length: 1301 characters
#
#      Chunk 2:
#        ID: paper-1-11-Key_Features_Of_a_Tool
#        Metadata: {'chunk_number': 11, 'section_category': 'Key Features Of a Tool', 'paper_id': 1, 'page_number': 3}
#        Page Number: 3
#        Chunk Number: 11
#        Text Preview: dataset to dataset. But in order to ensure that your data cleaning operation is carried out correctly each time, it is crucial to build a template for...
#        Text Length: 1292 characters
#
#      Chunk 3:
#        ID: paper-1-12-Key_Features_Of_a_Tool
#        Metadata: {'page_number': 3, 'paper_id': 1, 'section_category': 'Key Features Of a Tool', 'chunk_number': 12}
#        Page Number: 3
#        Chunk Number: 12
#        Text Preview: includes criteria for creating strong passwords and spell checking. D. Model development The process of developing a model is iterative; numerous mode...
#        Text Length: 1335 characters
#
#      Chunk 4:
#        ID: paper-1-13-Key_Features_Of_a_Tool
#        Metadata: {'chunk_number': 13, 'page_number': 3, 'section_category': 'Key Features Of a Tool', 'paper_id': 1}
#        Page Number: 3
#        Chunk Number: 13
#        Text Preview: the provided data set, a learning algorithm learns or predicts the model parameters before updating these values over time. These variables are added ...
#        Text Length: 1251 characters
#
#      Chunk 5:
#        ID: paper-1-14-Key_Features_Of_a_Tool
#        Metadata: {'chunk_number': 14, 'paper_id': 1, 'section_category': 'Key Features Of a Tool', 'page_number': 3}
#        Page Number: 3
#        Chunk Number: 14
#        Text Preview: as model validation. This usually entails verifying that the model is accurate in the setting of its intended application. The process of updating a ﬁ...
#        Text Length: 1191 characters
#
#      Chunk 6:
#        ID: paper-1-15-Key_Features_Of_a_Tool
#        Metadata: {'page_number': 3, 'paper_id': 1, 'section_category': 'Key Features Of a Tool', 'chunk_number': 15}
#        Page Number: 3
#        Chunk Number: 15
#        Text Preview: apply. B. Open source If developers want to open source their code, sharing work- ﬂow steps and models between organizations is very simple thanks to ...
#        Text Length: 1197 characters
#
#      Chunk 7:
#        ID: paper-1-16-Key_Features_Of_a_Tool
#        Metadata: {'section_category': 'Key Features Of a Tool', 'page_number': 3, 'chunk_number': 16, 'paper_id': 1}
#        Page Number: 3
#        Chunk Number: 16
#        Text Preview: run the code. An MLﬂow project is deﬁned in a simple YAML ﬁle called MLproject. The appropriate environment for the project will be automatically crea...
#        Text Length: 1238 characters
#
#      Chunk 8:
#        ID: paper-1-17-Key_Features_Of_a_Tool
#        Metadata: {'chunk_number': 17, 'section_category': 'Key Features Of a Tool', 'paper_id': 1, 'page_number': 3}
#        Page Number: 3
#        Chunk Number: 17
#        Text Preview: serves as a model for stage transitions. • CI/CD Workﬂow Integration: Recording stage transitions and requesting, reviewing, and approving changes as ...
#        Text Length: 1317 characters
#
#      Chunk 9:
#        ID: paper-1-18-Key_Features_Of_a_Tool
#        Metadata: {'chunk_number': 18, 'paper_id': 1, 'page_number': 3, 'section_category': 'Key Features Of a Tool'}
#        Page Number: 3
#        Chunk Number: 18
#        Text Preview: and if they don’t mind working on a platform that is undergoing an upgrade. However, this implies that they might probably produce better outcomes and...
#        Text Length: 1297 characters
#
#      Chunk 10:
#        ID: paper-1-19-Key_Features_Of_a_Tool
#        Metadata: {'section_category': 'Key Features Of a Tool', 'paper_id': 1, 'chunk_number': 19, 'page_number': 3}
#        Page Number: 3
#        Chunk Number: 19
#        Text Preview: production, comes into play while discussing the MLOps platform. It is a machine learning platform that programmers use frequently to support the adva...
#        Text Length: 642 characters
#
#   📑 Section: Conclusion
#      Chunks in this section: 4
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-20-Conclusion
#        Metadata: {'page_number': 6, 'paper_id': 1, 'section_category': 'Conclusion', 'chunk_number': 20}
#        Page Number: 6
#        Chunk Number: 20
#        Text Preview: VII. CONCLUSION Given all the discussion about machine learning, the future will surely be data-driven. Organizations can employ machine learning capa...
#        Text Length: 1421 characters
#
#      Chunk 2:
#        ID: paper-1-21-Conclusion
#        Metadata: {'chunk_number': 21, 'paper_id': 1, 'section_category': 'Conclusion', 'page_number': 6}
#        Page Number: 6
#        Chunk Number: 21
#        Text Preview: and Challenges. IEEE Transactions on Software Engineering, 44(11), 1024–1038. https://doi.org/10.1109/tse.2017.2754374 [5] M. Senapathi, J. Buchan, an...
#        Text Length: 1421 characters
#
#      Chunk 3:
#        ID: paper-1-22-Conclusion
#        Metadata: {'chunk_number': 22, 'page_number': 6, 'paper_id': 1, 'section_category': 'Conclusion'}
#        Page Number: 6
#        Chunk Number: 22
#        Text Preview: NIPS, 2015. [11] B. Nushi, E. Kamar, E. Horvitz, and D. Kossmann, “On human intellect and machine failures: Troubleshooting integrative machine learni...
#        Text Length: 1346 characters
#
#      Chunk 4:
#        ID: paper-1-23-Conclusion
#        Metadata: {'page_number': 6, 'chunk_number': 23, 'section_category': 'Conclusion', 'paper_id': 1}
#        Page Number: 6
#        Chunk Number: 23
#        Text Preview: D. Gunning, “Explainable artiﬁcial intelligence (XAI),” Defense Ad- vanced Research Projects Agency (DARPA), 2017. [19] T. Gebru, J. Morgenstern, B. V...
#        Text Length: 814 characters
#
#
# ================================================================================
# 📄 PAPER: 2
#    Total Chunks: 47
# ================================================================================
#
#   📑 Section: Introduction
#      Chunks in this section: 7
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-3-Introduction
#        Metadata: {'paper_id': 2, 'chunk_number': 3, 'page_number': 1, 'section_category': 'Introduction'}
#        Page Number: 1
#        Chunk Number: 3
#        Text Preview: provides a single interface for the deployment of fine-grained traffic steering policies. StEERING provides scalability in three distinct ways. First,...
#        Text Length: 1340 characters
#
#      Chunk 2:
#        ID: paper-1-4-Introduction
#        Metadata: {'paper_id': 2, 'page_number': 1, 'chunk_number': 4, 'section_category': 'Introduction'}
#        Page Number: 1
#        Chunk Number: 4
#        Text Preview: architecture to reduce the state required at each switch, by leveraging new features available in OpenFlow 1.1 (the proposal is applicable to later ve...
#        Text Length: 1292 characters
#
#      Chunk 3:
#        ID: paper-1-5-Introduction
#        Metadata: {'paper_id': 2, 'chunk_number': 5, 'page_number': 1, 'section_category': 'Introduction'}
#        Page Number: 1
#        Chunk Number: 5
#        Text Preview: existing approaches in §II. §III presents an overview of the StEERING architecture and §IV describes each component in details. §V describes our algor...
#        Text Length: 1296 characters
#
#      Chunk 4:
#        ID: paper-1-6-Introduction
#        Metadata: {'chunk_number': 6, 'page_number': 1, 'section_category': 'Introduction', 'paper_id': 2}
#        Page Number: 1
#        Chunk Number: 6
#        Text Preview: chains .{ J( J( PBR .{ J( J( Pswitch .{ .{ J( StEERING .{ .{ .{ Internet Open- Scala- ness bility J( J( .{ J( .{ J( .{ J( .{ .{ lAJ:SLb 1. :SUMMARY OF...
#        Text Length: 1204 characters
#
#      Chunk 5:
#        ID: paper-1-7-Introduction
#        Metadata: {'chunk_number': 7, 'page_number': 1, 'section_category': 'Introduction', 'paper_id': 2}
#        Page Number: 1
#        Chunk Number: 7
#        Text Preview: inflexible and prone to mis-configurations. Limitations of existing solutions: The operators today still do not have protocols or tools available to p...
#        Text Length: 1322 characters
#
#      Chunk 6:
#        ID: paper-1-8-Introduction
#        Metadata: {'chunk_number': 8, 'page_number': 1, 'section_category': 'Introduction', 'paper_id': 2}
#        Page Number: 1
#        Chunk Number: 8
#        Text Preview: UTC from IEEE Xplore. Restrictions apply. Traffic Bypass Traffic Steering OF Protocol StEERING Service Protocol Fig. 2. System architecture StEERING C...
#        Text Length: 1262 characters
#
#      Chunk 7:
#        ID: paper-1-9-Introduction
#        Metadata: {'section_category': 'Introduction', 'paper_id': 2, 'page_number': 1, 'chunk_number': 9}
#        Page Number: 1
#        Chunk Number: 9
#        Text Preview: Therefore, it is hard to scale with the number of subscriber/application combinations. Location of the services: Even if we have the perfect steer­ in...
#        Text Length: 615 characters
#
#   📑 Section: System Overview
#      Chunks in this section: 3
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-10-System_Overview
#        Metadata: {'page_number': 3, 'chunk_number': 10, 'paper_id': 2, 'section_category': 'System Overview'}
#        Page Number: 3
#        Chunk Number: 10
#        Text Preview: III. SYSTEM OVERVIEW StEERING is built upon the software-defined networking (SDN) concept. SDN is a new network architecture that introduces programma...
#        Text Length: 1284 characters
#
#      Chunk 2:
#        ID: paper-1-11-System_Overview
#        Metadata: {'chunk_number': 11, 'paper_id': 2, 'section_category': 'System Overview', 'page_number': 3}
#        Page Number: 3
#        Chunk Number: 11
#        Text Preview: module of the control logic is an algorithm that periodically runs to determine the best locations for inline services. The openflow rules are used to...
#        Text Length: 1181 characters
#
#      Chunk 3:
#        ID: paper-1-12-System_Overview
#        Metadata: {'paper_id': 2, 'page_number': 3, 'section_category': 'System Overview', 'chunk_number': 12}
#        Page Number: 3
#        Chunk Number: 12
#        Text Preview: the OF controller. The service policy for each flow is determined by the operator but can also be specified by the subscriber, i.e., cus­ tomers of th...
#        Text Length: 343 characters
#
#   📑 Section: Basic Design Components
#      Chunks in this section: 13
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-13-Basic_Design_Components
#        Metadata: {'chunk_number': 13, 'paper_id': 2, 'page_number': 3, 'section_category': 'Basic Design Components'}
#        Page Number: 3
#        Chunk Number: 13
#        Text Preview: IV. BASIC DESIGN COMPONENTS The data plane (forwarding) of StEERING can be easily configured and scaled as the number of subscriber/application combin...
#        Text Length: 1311 characters
#
#      Chunk 2:
#        ID: paper-1-14-Basic_Design_Components
#        Metadata: {'paper_id': 2, 'section_category': 'Basic Design Components', 'page_number': 3, 'chunk_number': 14}
#        Page Number: 3
#        Chunk Number: 14
#        Text Preview: dstiP. proto, port Action: set metadata(serv_set) Path status table Key: input port Action: modify metadata(serv_set) Next Ost table incoming _ Key: i...
#        Text Length: 1245 characters
#
#      Chunk 3:
#        ID: paper-1-15-Basic_Design_Components
#        Metadata: {'chunk_number': 15, 'section_category': 'Basic Design Components', 'page_number': 3, 'paper_id': 2}
#        Page Number: 3
#        Chunk Number: 15
#        Text Preview: paths. Packets arriving on transit ports are simply forwarded using their destination MAC addresses. All packets traversing the steering network are c...
#        Text Length: 1311 characters
#
#      Chunk 4:
#        ID: paper-1-16-Basic_Design_Components
#        Metadata: {'page_number': 3, 'section_category': 'Basic Design Components', 'chunk_number': 16, 'paper_id': 2}
#        Page Number: 3
#        Chunk Number: 16
#        Text Preview: the key, which identifies the direction of the packet (upstream vs. downstream) and the type of the port the packet was received on (node vs. transit ...
#        Text Length: 1171 characters
#
#      Chunk 5:
#        ID: paper-1-17-Basic_Design_Components
#        Metadata: {'chunk_number': 17, 'page_number': 3, 'paper_id': 2, 'section_category': 'Basic Design Components'}
#        Page Number: 3
#        Chunk Number: 17
#        Text Preview: port number. This table is used to modify the subscriber's default service set according to any static L3-L4 application policies. Based on this infor...
#        Text Length: 1139 characters
#
#      Chunk 6:
#        ID: paper-1-18-Basic_Design_Components
#        Metadata: {'page_number': 3, 'paper_id': 2, 'chunk_number': 18, 'section_category': 'Basic Design Components'}
#        Page Number: 3
#        Chunk Number: 18
#        Text Preview: and the previous service, the service set is modified to exclude the previous service and all other services that precede it. Next Destination table: ...
#        Text Length: 1234 characters
#
#      Chunk 7:
#        ID: paper-1-19-Basic_Design_Components
#        Metadata: {'section_category': 'Basic Design Components', 'page_number': 3, 'paper_id': 2, 'chunk_number': 19}
#        Page Number: 3
#        Chunk Number: 19
#        Text Preview: corresponding node port. C. Handle dynamics with the Microflow Table Microflow table is added to handle dynamically generated rules. Usually operators...
#        Text Length: 1254 characters
#
#      Chunk 8:
#        ID: paper-1-20-Basic_Design_Components
#        Metadata: {'chunk_number': 20, 'paper_id': 2, 'page_number': 3, 'section_category': 'Basic Design Components'}
#        Page Number: 3
#        Chunk Number: 20
#        Text Preview: communicate the information among different tables and associated actions [8]. Intermediate results from one table are communicated to other tables us...
#        Text Length: 1185 characters
#
#      Chunk 9:
#        ID: paper-1-21-Basic_Design_Components
#        Metadata: {'section_category': 'Basic Design Components', 'chunk_number': 21, 'paper_id': 2, 'page_number': 3}
#        Page Number: 3
#        Chunk Number: 21
#        Text Preview: indicates whether it's upstream (0) or down­ stream (1). The following N-bit vector defines the service set, encoding for N number of services. The en...
#        Text Length: 1153 characters
#
#      Chunk 10:
#        ID: paper-1-22-Basic_Design_Components
#        Metadata: {'page_number': 3, 'chunk_number': 22, 'paper_id': 2, 'section_category': 'Basic Design Components'}
#        Page Number: 3
#        Chunk Number: 22
#        Text Preview: bit to represent a service (indicating whether or not it should be applied), and there is only one instance of each service. This encoding can be ex­ ...
#        Text Length: 1134 characters
#
#      Chunk 11:
#        ID: paper-1-23-Basic_Design_Components
#        Metadata: {'paper_id': 2, 'section_category': 'Basic Design Components', 'page_number': 3, 'chunk_number': 23}
#        Page Number: 3
#        Chunk Number: 23
#        Text Preview: croflow table, as it is not derived from the static configuration. Below, an example is given on how the metadata field is matched or updated. This ex...
#        Text Length: 1179 characters
#
#      Chunk 12:
#        ID: paper-1-24-Basic_Design_Components
#        Metadata: {'page_number': 3, 'paper_id': 2, 'section_category': 'Basic Design Components', 'chunk_number': 24}
#        Page Number: 3
#        Chunk Number: 24
#        Text Preview: I 3 dir=down S3 MAC set srcMAC, output to port 3 4 dir=up Application Table Path Status Table Dir. I IP Addr I Proto I Port I Action Ingress Port I Ac...
#        Text Length: 1093 characters
#
#      Chunk 13:
#        ID: paper-1-25-Basic_Design_Components
#        Metadata: {'paper_id': 2, 'chunk_number': 25, 'page_number': 3, 'section_category': 'Basic Design Components'}
#        Page Number: 3
#        Chunk Number: 25
#        Text Preview: Subscriber table using the subscriber informa­ tion. Using both the direction bit (Up) and the Subscriber IP address, the first rule is selected, i.e....
#        Text Length: 538 characters
#
#   📑 Section: Service Placement Module
#      Chunks in this section: 5
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-26-Service_Placement_Module
#        Metadata: {'section_category': 'Service Placement Module', 'paper_id': 2, 'chunk_number': 26, 'page_number': 6}
#        Page Number: 6
#        Chunk Number: 26
#        Text Preview: V. SERVICE PLACEMENT MODULE Given the ability to perform flexible routing across services demonstrated above, we do not require the services to be pla...
#        Text Length: 1267 characters
#
#      Chunk 2:
#        ID: paper-1-27-Service_Placement_Module
#        Metadata: {'paper_id': 2, 'page_number': 6, 'section_category': 'Service Placement Module', 'chunk_number': 27}
#        Page Number: 6
#        Chunk Number: 27
#        Text Preview: network on the right. The ordering of the inline services to be traversed is determined according to subscribers' policies: 90% of the subscribers req...
#        Text Length: 1179 characters
#
#      Chunk 3:
#        ID: paper-1-28-Service_Placement_Module
#        Metadata: {'page_number': 6, 'paper_id': 2, 'section_category': 'Service Placement Module', 'chunk_number': 28}
#        Page Number: 6
#        Chunk Number: 28
#        Text Preview: be more complicated to find the optimal solution. B. Problem definition and a greedy solution We formulate the service placement problem as an opti­ m...
#        Text Length: 1134 characters
#
#      Chunk 4:
#        ID: paper-1-29-Service_Placement_Module
#        Metadata: {'section_category': 'Service Placement Module', 'chunk_number': 29, 'paper_id': 2, 'page_number': 6}
#        Page Number: 6
#        Chunk Number: 29
#        Text Preview: the subscriber's traffic. The objective is to find a subset M (I MI = 181 = h) of the locations among all candidates N = lVI, and place the services i...
#        Text Length: 1168 characters
#
#      Chunk 5:
#        ID: paper-1-30-Service_Placement_Module
#        Metadata: {'paper_id': 2, 'page_number': 6, 'chunk_number': 30, 'section_category': 'Service Placement Module'}
#        Page Number: 6
#        Chunk Number: 30
#        Text Preview: Two services are dependent if they appear consecutively in the service chain requirement of some subscribers, and the degree of this dependency is det...
#        Text Length: 621 characters
#
#   📑 Section: Implementation and Evaluation
#      Chunks in this section: 12
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-31-Implementation_and_Evaluation
#        Metadata: {'paper_id': 2, 'page_number': 7, 'section_category': 'Implementation and Evaluation', 'chunk_number': 31}
#        Page Number: 7
#        Chunk Number: 31
#        Text Preview: VI. IMPLEMENTATION AND EVALUATION We implement StEERING in a testbed as shown in Fig­ ure 7. Our control plane is built using the NOX OpenFlow control...
#        Text Length: 1306 characters
#
#      Chunk 2:
#        ID: paper-1-32-Implementation_and_Evaluation
#        Metadata: {'paper_id': 2, 'chunk_number': 32, 'section_category': 'Implementation and Evaluation', 'page_number': 7}
#        Page Number: 7
#        Chunk Number: 32
#        Text Preview: run as application on top of NOX, as shown in Figure 7. The Steering Config Module maintains databases of the network topology, the service policies a...
#        Text Length: 1283 characters
#
#      Chunk 3:
#        ID: paper-1-33-Implementation_and_Evaluation
#        Metadata: {'chunk_number': 33, 'section_category': 'Implementation and Evaluation', 'paper_id': 2, 'page_number': 7}
#        Page Number: 7
#        Chunk Number: 33
#        Text Preview: in the flow notification message (i.e., 5-tuple) with the originating subscriber as well as its assigned service chain. Rule timeout: To reduce the nu...
#        Text Length: 1296 characters
#
#      Chunk 4:
#        ID: paper-1-34-Implementation_and_Evaluation
#        Metadata: {'section_category': 'Implementation and Evaluation', 'page_number': 7, 'paper_id': 2, 'chunk_number': 34}
#        Page Number: 7
#        Chunk Number: 34
#        Text Preview: with a host processor (pow­ erPC) used to run initialization, control and management tasks. The host processor runs a small footprint distribution of ...
#        Text Length: 1230 characters
#
#      Chunk 5:
#        ID: paper-1-35-Implementation_and_Evaluation
#        Metadata: {'chunk_number': 35, 'section_category': 'Implementation and Evaluation', 'page_number': 7, 'paper_id': 2}
#        Page Number: 7
#        Chunk Number: 35
#        Text Preview: Microflow table are performed in parallel in the TOPsearch I phase, as they can operate on the metadata field independently. The Path Status and Next ...
#        Text Length: 1130 characters
#
#      Chunk 6:
#        ID: paper-1-36-Implementation_and_Evaluation
#        Metadata: {'paper_id': 2, 'chunk_number': 36, 'section_category': 'Implementation and Evaluation', 'page_number': 7}
#        Page Number: 7
#        Chunk Number: 36
#        Text Preview: 40000 :l Z 20000 0 0 500 1000 1500 2000 2500 3000 3500 Time (sec) Fig. 9. Table size increases over time controller-service protocol, called the StEER...
#        Text Length: 1246 characters
#
#      Chunk 7:
#        ID: paper-1-37-Implementation_and_Evaluation
#        Metadata: {'page_number': 7, 'section_category': 'Implementation and Evaluation', 'chunk_number': 37, 'paper_id': 2}
#        Page Number: 7
#        Chunk Number: 37
#        Text Preview: in­ creases linearly as the sum of subscribers and applications, while the pswitch approach grows as the product of subscribers and applications. We s...
#        Text Length: 1113 characters
#
#      Chunk 8:
#        ID: paper-1-38-Implementation_and_Evaluation
#        Metadata: {'chunk_number': 38, 'page_number': 7, 'paper_id': 2, 'section_category': 'Implementation and Evaluation'}
#        Page Number: 7
#        Chunk Number: 38
#        Text Preview: pswitch approach. The advantage comes from the separation of subscriber policies from application policies, allowing the independent scaling of rules ...
#        Text Length: 1175 characters
#
#      Chunk 9:
#        ID: paper-1-39-Implementation_and_Evaluation
#        Metadata: {'paper_id': 2, 'chunk_number': 39, 'section_category': 'Implementation and Evaluation', 'page_number': 7}
#        Page Number: 7
#        Chunk Number: 39
#        Text Preview: packet size of 64 bytes, which represents 29.8 Mpps. This throughput is, in fact, limited by the capability of our current traffic generator. In the f...
#        Text Length: 1206 characters
#
#      Chunk 10:
#        ID: paper-1-40-Implementation_and_Evaluation
#        Metadata: {'section_category': 'Implementation and Evaluation', 'chunk_number': 40, 'paper_id': 2, 'page_number': 7}
#        Page Number: 7
#        Chunk Number: 40
#        Text Preview: __  __ \[ __  __ L-] __  __ L-^ o 0.02 0.04 0.06 0.08 0.1 0.12 0.14 0.16 0.18 0.2 Latency (sec) Fig. I I . Delay distribution with 3 services deplo...
#        Text Length: 1082 characters
#
#      Chunk 11:
#        ID: paper-1-41-Implementation_and_Evaluation
#        Metadata: {'paper_id': 2, 'section_category': 'Implementation and Evaluation', 'chunk_number': 41, 'page_number': 7}
#        Page Number: 7
#        Chunk Number: 41
#        Text Preview: until the time when rules are sent out. We show the average response time across all subscribers as the rate increases in the y-axis of Figure 10. Cle...
#        Text Length: 1196 characters
#
#      Chunk 12:
#        ID: paper-1-42-Implementation_and_Evaluation
#        Metadata: {'paper_id': 2, 'page_number': 7, 'chunk_number': 42, 'section_category': 'Implementation and Evaluation'}
#        Page Number: 7
#        Chunk Number: 42
#        Text Preview: 02,2025 at 21:26:02 UTC from IEEE Xplore. Restrictions apply. the random scheme needs 80ms. We also vary the number of services in Figure 12. The adva...
#        Text Length: 404 characters
#
#   📑 Section: Related Work
#      Chunks in this section: 2
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-43-Related_Work
#        Metadata: {'page_number': 10, 'section_category': 'Related Work', 'chunk_number': 43, 'paper_id': 2}
#        Page Number: 10
#        Chunk Number: 43
#        Text Preview: VII. RELATED WORK Our work contributes to and draws inspiration from a rich corpus of work in middlebox management, Software-Defined Networking (SDN) ...
#        Text Length: 1329 characters
#
#      Chunk 2:
#        ID: paper-1-44-Related_Work
#        Metadata: {'section_category': 'Related Work', 'page_number': 10, 'paper_id': 2, 'chunk_number': 44}
#        Page Number: 10
#        Chunk Number: 44
#        Text Preview: large body of work on improving the SDN programmability is orthogonal to our work [25], [26], [27], and thus can be integrated into StEERING in the fu...
#        Text Length: 155 characters
#
#   📑 Section: Conclusion
#      Chunks in this section: 1
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-45-Conclusion
#        Metadata: {'page_number': 10, 'section_category': 'Conclusion', 'chunk_number': 45, 'paper_id': 2}
#        Page Number: 10
#        Chunk Number: 45
#        Text Preview: VIII. CONCLUSION We presented StEERING for managing traffic through middleboxes in the mobile and broadband network. Built on top of SDN, StEERING can...
#        Text Length: 526 characters
#
#   📑 Section: Acknowledgments
#      Chunks in this section: 4
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-46-Acknowledgments
#        Metadata: {'section_category': 'Acknowledgments', 'paper_id': 2, 'page_number': 10, 'chunk_number': 46}
#        Page Number: 10
#        Chunk Number: 46
#        Text Preview: ACKNOWLEDGMENTS The authors would like to thank Frank Ruhl and Daniel Kirkham of Telstra's Innovation and Strategy team. The au­ thors are also gratef...
#        Text Length: 1188 characters
#
#      Chunk 2:
#        ID: paper-1-47-Acknowledgments
#        Metadata: {'chunk_number': 47, 'section_category': 'Acknowledgments', 'page_number': 10, 'paper_id': 2}
#        Page Number: 10
#        Chunk Number: 47
#        Text Preview: "Future architectures for middlebox processing services on the internet and in the cloud," Master's theSIS, EECS Department, University of California,...
#        Text Length: 1516 characters
#
#      Chunk 3:
#        ID: paper-1-48-Acknowledgments
#        Metadata: {'section_category': 'Acknowledgments', 'page_number': 10, 'paper_id': 2, 'chunk_number': 48}
#        Page Number: 10
#        Chunk Number: 48
#        Text Preview: Proc. ACM SIGCOMM IMC, 2003. M. Honda, Y. Nishida, C. Raiciu, A. Greenhalgh, M. Handley, and H. Tokuda, "Is it still possible to extend tcp?," in Proc...
#        Text Length: 1175 characters
#
#      Chunk 4:
#        ID: paper-1-49-Acknowledgments
#        Metadata: {'chunk_number': 49, 'paper_id': 2, 'page_number': 10, 'section_category': 'Acknowledgments'}
#        Page Number: 10
#        Chunk Number: 49
#        Text Preview: N. Foster, R. Harrison, M. J. Freedman, C. Monsanto, J. Rexford, A. Story, and D. Walker, "Frenetic: a network programming language," in Proceedings o...
#        Text Length: 817 characters
#
#
# ================================================================================
# 📄 PAPER: 3
#    Total Chunks: 24
# ================================================================================
#
#   📑 Section: Software Development Life Cycles
#      Chunks in this section: 15
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-3-Software_Development_Life_Cycles
#        Metadata: {'chunk_number': 3, 'page_number': 1, 'section_category': 'Software Development Life Cycles', 'paper_id': 3}
#        Page Number: 1
#        Chunk Number: 3
#        Text Preview: II. SOFTWARE DEVELOPMENT LIFE CYCLES A SDLC is a collection of methodologies for structuring, planning, and executing tasks related to software develo...
#        Text Length: 1344 characters
#
#      Chunk 2:
#        ID: paper-1-4-Software_Development_Life_Cycles
#        Metadata: {'chunk_number': 4, 'section_category': 'Software Development Life Cycles', 'page_number': 1, 'paper_id': 3}
#        Page Number: 1
#        Chunk Number: 4
#        Text Preview: phases and introduced better methods for managing risk [13]. $Q$JLOH6RIWZDUH'HYHORSPHQW/LIH&\FOH 0RGHOIRU0DFKLQH/HDUQLQJ$SSOLFDWLRQ 'HYHORS...
#        Text Length: 1539 characters
#
#      Chunk 3:
#        ID: paper-1-5-Software_Development_Life_Cycles
#        Metadata: {'chunk_number': 5, 'page_number': 1, 'paper_id': 3, 'section_category': 'Software Development Life Cycles'}
#        Page Number: 1
#        Chunk Number: 5
#        Text Preview: each member of the team to be better informed and make better decisions. Agile teams are typically cross- functional and more efficient as team member...
#        Text Length: 1345 characters
#
#      Chunk 4:
#        ID: paper-1-6-Software_Development_Life_Cycles
#        Metadata: {'section_category': 'Software Development Life Cycles', 'chunk_number': 6, 'paper_id': 3, 'page_number': 1}
#        Page Number: 1
#        Chunk Number: 6
#        Text Preview: are repeated in short iterations (Fig.2). Automation of the key steps allows the teams to reduce the time between iterations and forms the backbone of...
#        Text Length: 1458 characters
#
#      Chunk 5:
#        ID: paper-1-7-Software_Development_Life_Cycles
#        Metadata: {'paper_id': 3, 'page_number': 1, 'chunk_number': 7, 'section_category': 'Software Development Life Cycles'}
#        Page Number: 1
#        Chunk Number: 7
#        Text Preview: machine learning application development. Data, hidden technical debt and the need for iterative experimentation are the main technical challenges of ...
#        Text Length: 1332 characters
#
#      Chunk 6:
#        ID: paper-1-8-Software_Development_Life_Cycles
#        Metadata: {'section_category': 'Software Development Life Cycles', 'chunk_number': 8, 'page_number': 1, 'paper_id': 3}
#        Page Number: 1
#        Chunk Number: 8
#        Text Preview: processes have largely developed based on workflows developed for data science and data mining, and therefore reflects the data dependency of machine ...
#        Text Length: 1531 characters
#
#      Chunk 7:
#        ID: paper-1-9-Software_Development_Life_Cycles
#        Metadata: {'page_number': 1, 'chunk_number': 9, 'section_category': 'Software Development Life Cycles', 'paper_id': 3}
#        Page Number: 1
#        Chunk Number: 9
#        Text Preview: feedback loops due to dependencies between data or between models are difficult to detect and debug. Software modules to continuously monitor the perf...
#        Text Length: 1450 characters
#
#      Chunk 8:
#        ID: paper-1-10-Software_Development_Life_Cycles
#        Metadata: {'section_category': 'Software Development Life Cycles', 'paper_id': 3, 'chunk_number': 10, 'page_number': 1}
#        Page Number: 1
#        Chunk Number: 10
#        Text Preview: of model training, evaluation, integration, deployment, and monitoring is key to facilitating data-centric experimentation. E. Machine Learning Operat...
#        Text Length: 1348 characters
#
#      Chunk 9:
#        ID: paper-1-11-Software_Development_Life_Cycles
#        Metadata: {'page_number': 1, 'paper_id': 3, 'section_category': 'Software Development Life Cycles', 'chunk_number': 11}
#        Page Number: 1
#        Chunk Number: 11
#        Text Preview: label consistency to the success of MLOps outcomes beyond this phase [27] [25] [24]. An MLOps framework is an essential feature for data-centric machi...
#        Text Length: 1371 characters
#
#      Chunk 10:
#        ID: paper-1-12-Software_Development_Life_Cycles
#        Metadata: {'section_category': 'Software Development Life Cycles', 'paper_id': 3, 'chunk_number': 12, 'page_number': 1}
#        Page Number: 1
#        Chunk Number: 12
#        Text Preview: machine learning application development. The framework was founded on the following design goals: (1) Agile Authorized licensed use limited to: INTER...
#        Text Length: 1530 characters
#
#      Chunk 11:
#        ID: paper-1-13-Software_Development_Life_Cycles
#        Metadata: {'chunk_number': 13, 'page_number': 1, 'paper_id': 3, 'section_category': 'Software Development Life Cycles'}
#        Page Number: 1
#        Chunk Number: 13
#        Text Preview: using separate or out- sourced teams for data labelling. Fig. 6 shows how the MLASDLC can be used through iterative agile sprints alongside a parallel...
#        Text Length: 1298 characters
#
#      Chunk 12:
#        ID: paper-1-14-Software_Development_Life_Cycles
#        Metadata: {'section_category': 'Software Development Life Cycles', 'page_number': 1, 'chunk_number': 14, 'paper_id': 3}
#        Page Number: 1
#        Chunk Number: 14
#        Text Preview: architecture of each module was designed during this phase. This phase forks into two parallel processes. The software design sub-process will focus o...
#        Text Length: 1291 characters
#
#      Chunk 13:
#        ID: paper-1-15-Software_Development_Life_Cycles
#        Metadata: {'section_category': 'Software Development Life Cycles', 'paper_id': 3, 'page_number': 1, 'chunk_number': 15}
#        Page Number: 1
#        Chunk Number: 15
#        Text Preview: to build and test the user application, and configuration and delivery system, MLOps pipelines and the DevOps pipelines. MLOps are used to integrate t...
#        Text Length: 1412 characters
#
#      Chunk 14:
#        ID: paper-1-16-Software_Development_Life_Cycles
#        Metadata: {'chunk_number': 16, 'paper_id': 3, 'section_category': 'Software Development Life Cycles', 'page_number': 1}
#        Page Number: 1
#        Chunk Number: 16
#        Text Preview: used for monitoring the performance of the model and data during serving. The model selection and training phase is broken into several sub-phases (Fi...
#        Text Length: 1386 characters
#
#      Chunk 15:
#        ID: paper-1-17-Software_Development_Life_Cycles
#        Metadata: {'chunk_number': 17, 'section_category': 'Software Development Life Cycles', 'page_number': 1, 'paper_id': 3}
#        Page Number: 1
#        Chunk Number: 17
#        Text Preview: monitoring The application software and machine learning modules are integrated into a single system when the two sub- processes converge. Automation ...
#        Text Length: 1334 characters
#
#   📑 Section: Evaluation
#      Chunks in this section: 3
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-18-Evaluation
#        Metadata: {'page_number': 5, 'section_category': 'Evaluation', 'paper_id': 3, 'chunk_number': 18}
#        Page Number: 5
#        Chunk Number: 18
#        Text Preview: V. EVALUATION This framework is the result of combining our knowledge and experience of software development with the practices we developed for machi...
#        Text Length: 1303 characters
#
#      Chunk 2:
#        ID: paper-1-19-Evaluation
#        Metadata: {'chunk_number': 19, 'paper_id': 3, 'section_category': 'Evaluation', 'page_number': 5}
#        Page Number: 5
#        Chunk Number: 19
#        Text Preview: the final application is designed and developed alongside machine learning model development. All category 1 projects used sample data or real-world d...
#        Text Length: 1341 characters
#
#      Chunk 3:
#        ID: paper-1-20-Evaluation
#        Metadata: {'section_category': 'Evaluation', 'paper_id': 3, 'page_number': 5, 'chunk_number': 20}
#        Page Number: 5
#        Chunk Number: 20
#        Text Preview: available data, and the feasibility of the project before moving onto the primary phases of the MLASDLC. Authorized licensed use limited to: INTERNATI...
#        Text Length: 274 characters
#
#   📑 Section: Discussion
#      Chunks in this section: 6
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-21-Discussion
#        Metadata: {'chunk_number': 21, 'paper_id': 3, 'section_category': 'Discussion', 'page_number': 6}
#        Page Number: 6
#        Chunk Number: 21
#        Text Preview: VI. DISCUSSION The MLASDLC is an operationalization of the processes we have established for developing production grade machine learning applications...
#        Text Length: 1334 characters
#
#      Chunk 2:
#        ID: paper-1-22-Discussion
#        Metadata: {'chunk_number': 22, 'paper_id': 3, 'section_category': 'Discussion', 'page_number': 6}
#        Page Number: 6
#        Chunk Number: 22
#        Text Preview: manage their other software development projects. MLASDLC advocates wide-spread automation, thereby allowing for rapid iteration and testing using dat...
#        Text Length: 1459 characters
#
#      Chunk 3:
#        ID: paper-1-23-Discussion
#        Metadata: {'page_number': 6, 'section_category': 'Discussion', 'chunk_number': 23, 'paper_id': 3}
#        Page Number: 6
#        Chunk Number: 23
#        Text Preview: 1, pp. 1-6, 2019. [6] B. Qian, J. Su, Z. Wen, D. N. Jha, Y. Li, Y. Guan, D. Puthal, P. James, R. Yang, A. Zomaya, O. Rana, L. Wang and R. Ranjan, "Orc...
#        Text Length: 1250 characters
#
#      Chunk 4:
#        ID: paper-1-24-Discussion
#        Metadata: {'page_number': 6, 'chunk_number': 24, 'section_category': 'Discussion', 'paper_id': 3}
#        Page Number: 6
#        Chunk Number: 24
#        Text Preview: user guide, Addison Wesley Longman Publishing Co., 1999. [14] I. T. Christou, S. T. Ponis and E. Palaiologou, "Using the Agile Unified Process in Bank...
#        Text Length: 1366 characters
#
#      Chunk 5:
#        ID: paper-1-25-Discussion
#        Metadata: {'paper_id': 3, 'page_number': 6, 'chunk_number': 25, 'section_category': 'Discussion'}
#        Page Number: 6
#        Chunk Number: 25
#        Text Preview: 2021]. [21] D. Scully, G. Holt, D. Golovin, E. Davydov, T. Phillips, D. Ebner, V. Chaudhary, M. Young and D. Dennison, "Hidden Technical Debt in Machi...
#        Text Length: 1492 characters
#
#      Chunk 6:
#        ID: paper-1-26-Discussion
#        Metadata: {'paper_id': 3, 'page_number': 6, 'chunk_number': 26, 'section_category': 'Discussion'}
#        Page Number: 6
#        Chunk Number: 26
#        Text Preview: O. Spjuth, J. Frid and A. Hellander, "The machine learning life cycle and the cloud: implications for drug discovery," Expert Opin Drug Discov., pp. 1...
#        Text Length: 329 characters
#
#
# ================================================================================
# 📄 PAPER: 4
#    Total Chunks: 25
# ================================================================================
#
#   📑 Section: Motivation
#      Chunks in this section: 2
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-2-Motivation
#        Metadata: {'page_number': 1, 'section_category': 'Motivation', 'chunk_number': 2, 'paper_id': 4}
#        Page Number: 1
#        Chunk Number: 2
#        Text Preview: II. MOTIVATION Our large-scale Smart City Living Lab at IIIT Hyderabad, with over 370 nodes across eight verticals, provides a real- world testing gro...
#        Text Length: 1545 characters
#
#      Chunk 2:
#        ID: paper-1-3-Motivation
#        Metadata: {'section_category': 'Motivation', 'paper_id': 4, 'chunk_number': 3, 'page_number': 1}
#        Page Number: 1
#        Chunk Number: 3
#        Text Preview: results. This research goes beyond performance comparisons. We aim to understand if and how fundamental architectural differences of interoperability ...
#        Text Length: 372 characters
#
#   📑 Section: Study Design and Execution
#      Chunks in this section: 10
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-4-Study_Design_and_Execution
#        Metadata: {'paper_id': 4, 'chunk_number': 4, 'section_category': 'Study Design and Execution', 'page_number': 2}
#        Page Number: 2
#        Chunk Number: 4
#        Text Preview: III. STUDY DESIGN AND EXECUTION In this section, we provide a comprehensive overview of the purpose and structure of this paper, breaking down our res...
#        Text Length: 1385 characters
#
#      Chunk 2:
#        ID: paper-1-5-Study_Design_and_Execution
#        Metadata: {'section_category': 'Study Design and Execution', 'paper_id': 4, 'chunk_number': 5, 'page_number': 2}
#        Page Number: 2
#        Chunk Number: 5
#        Text Preview: aims to provide an overview of the architectures under consideration, elucidating their fundamental features and functionalities. Research Question 2 ...
#        Text Length: 1408 characters
#
#      Chunk 3:
#        ID: paper-1-6-Study_Design_and_Execution
#        Metadata: {'section_category': 'Study Design and Execution', 'page_number': 2, 'paper_id': 4, 'chunk_number': 6}
#        Page Number: 2
#        Chunk Number: 6
#        Text Preview: our comparative analysis. Additionally, the host system was connected via Ethernet to minimize network- related variations. For reference and transpar...
#        Text Length: 1428 characters
#
#      Chunk 4:
#        ID: paper-1-7-Study_Design_and_Execution
#        Metadata: {'page_number': 2, 'chunk_number': 7, 'paper_id': 4, 'section_category': 'Study Design and Execution'}
#        Page Number: 2
#        Chunk Number: 7
#        Text Preview: conﬁgure various testing patterns to assess the performance of the three systems thor- oughly. Our evaluation encompassed two distinct scenarios: 1. S...
#        Text Length: 1391 characters
#
#      Chunk 5:
#        ID: paper-1-8-Study_Design_and_Execution
#        Metadata: {'chunk_number': 8, 'section_category': 'Study Design and Execution', 'paper_id': 4, 'page_number': 2}
#        Page Number: 2
#        Chunk Number: 8
#        Text Preview: until either system crashes or performance degradation occurs, with one test each for GET and POST operations, resulting in 6 additional tests. Finall...
#        Text Length: 1368 characters
#
#      Chunk 6:
#        ID: paper-1-9-Study_Design_and_Execution
#        Metadata: {'page_number': 2, 'section_category': 'Study Design and Execution', 'paper_id': 4, 'chunk_number': 9}
#        Page Number: 2
#        Chunk Number: 9
#        Text Preview: in real-world sce- narios. In total, we conducted 48 comprehensive tests, all executed over Ethernet connections. In subsequent sections of this paper...
#        Text Length: 1373 characters
#
#      Chunk 7:
#        ID: paper-1-10-Study_Design_and_Execution
#        Metadata: {'section_category': 'Study Design and Execution', 'chunk_number': 10, 'page_number': 2, 'paper_id': 4}
#        Page Number: 2
#        Chunk Number: 10
#        Text Preview: via plugins. Fig 2 shows an overview of the OM2M architecture. OM2M is a project written in Java and owned by the Eclipse Foundation. It is built as a...
#        Text Length: 1364 characters
#
#      Chunk 8:
#        ID: paper-1-11-Study_Design_and_Execution
#        Metadata: {'chunk_number': 11, 'page_number': 2, 'paper_id': 4, 'section_category': 'Study Design and Execution'}
#        Page Number: 2
#        Chunk Number: 11
#        Text Preview: (Autonomic Computing Service) for self-conﬁguration of M2M communications. ACS operates as an expert system, emulating human decision- making abilitie...
#        Text Length: 1393 characters
#
#      Chunk 9:
#        ID: paper-1-12-Study_Design_and_Execution
#        Metadata: {'page_number': 2, 'chunk_number': 12, 'paper_id': 4, 'section_category': 'Study Design and Execution'}
#        Page Number: 2
#        Chunk Number: 12
#        Text Preview: Windows, and Jupyter Notebooks. This adaptability enhances its deployment ﬂexibility. ACME primarily serves as an educational tool for learning IoT an...
#        Text Length: 1413 characters
#
#      Chunk 10:
#        ID: paper-1-13-Study_Design_and_Execution
#        Metadata: {'page_number': 2, 'paper_id': 4, 'chunk_number': 13, 'section_category': 'Study Design and Execution'}
#        Page Number: 2
#        Chunk Number: 13
#        Text Preview: Node JS [13], which is a high-performance network server that supports asynchronous I/O. Mobius supports MySQL as the database and HTTP, MQTT, CoAP, a...
#        Text Length: 1288 characters
#
#   📑 Section: Results
#      Chunks in this section: 4
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-14-Results
#        Metadata: {'chunk_number': 14, 'section_category': 'Results', 'paper_id': 4, 'page_number': 5}
#        Page Number: 5
#        Chunk Number: 14
#        Text Preview: IV. RESULTS This section presents the results of our comprehensive evaluation comparing the three systems: OM2M, Mobius, and ACME. The evaluation enco...
#        Text Length: 1254 characters
#
#      Chunk 2:
#        ID: paper-1-15-Results
#        Metadata: {'page_number': 5, 'chunk_number': 15, 'section_category': 'Results', 'paper_id': 4}
#        Page Number: 5
#        Chunk Number: 15
#        Text Preview: behaviour in the given situation, given its performance across all the other scenarios. 2) CPU Stats: Fig. 7 explores CPU usage trends in relation to ...
#        Text Length: 1359 characters
#
#      Chunk 3:
#        ID: paper-1-16-Results
#        Metadata: {'paper_id': 4, 'section_category': 'Results', 'page_number': 5, 'chunk_number': 16}
#        Page Number: 5
#        Chunk Number: 16
#        Text Preview: 432000 ACME 14 95000 Mobius 568 1600 TABLE I STRESS TESTING POST REQUESTS ON REAL WORKLOAD System Peak RPS 95th Avg Latency(ms) OM2M 3 207000 ACME 43 ...
#        Text Length: 1265 characters
#
#      Chunk 4:
#        ID: paper-1-17-Results
#        Metadata: {'chunk_number': 17, 'paper_id': 4, 'section_category': 'Results', 'page_number': 5}
#        Page Number: 5
#        Chunk Number: 17
#        Text Preview: Furthermore, Mobius achieved an exceptionally low 95th Avg Latency of 12 ms. This extensive evaluation consistently positions Mobius as the leading mi...
#        Text Length: 565 characters
#
#   📑 Section: Discussion
#      Chunks in this section: 3
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-18-Discussion
#        Metadata: {'page_number': 5, 'section_category': 'Discussion', 'paper_id': 4, 'chunk_number': 18}
#        Page Number: 5
#        Chunk Number: 18
#        Text Preview: V. DISCUSSION In this section, we will address the three research questions that guided our evaluation of IoT middleware platforms: RQ1, RQ2, and RQ3....
#        Text Length: 1422 characters
#
#      Chunk 2:
#        ID: paper-1-19-Discussion
#        Metadata: {'page_number': 5, 'paper_id': 4, 'chunk_number': 19, 'section_category': 'Discussion'}
#        Page Number: 5
#        Chunk Number: 19
#        Text Preview: OM2M: The OM2M architecture is characterized by its excep- tional modularity and extensibility, allowing the seamless inte- gration of specialized fun...
#        Text Length: 1450 characters
#
#      Chunk 3:
#        ID: paper-1-20-Discussion
#        Metadata: {'chunk_number': 20, 'page_number': 5, 'paper_id': 4, 'section_category': 'Discussion'}
#        Page Number: 5
#        Chunk Number: 20
#        Text Preview: complexity may be excessive for speciﬁc tasks, highlighting the balance between code quality and performance. How do different interoperability framew...
#        Text Length: 1491 characters
#
#   📑 Section: Related Work
#      Chunks in this section: 2
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-23-Related_Work
#        Metadata: {'page_number': 7, 'paper_id': 4, 'section_category': 'Related Work', 'chunk_number': 23}
#        Page Number: 7
#        Chunk Number: 23
#        Text Preview: VI. RELATED WORK Multiple studies have contributed to the in-depth analysis of IoT architecture using system-level concepts, including resilience, sca...
#        Text Length: 1460 characters
#
#      Chunk 2:
#        ID: paper-1-24-Related_Work
#        Metadata: {'page_number': 7, 'chunk_number': 24, 'paper_id': 4, 'section_category': 'Related Work'}
#        Page Number: 7
#        Chunk Number: 24
#        Text Preview: to better device interoperability and automated reasoning for autonomic behavior. The constraints of current M2M standards are addressed by this integ...
#        Text Length: 1397 characters
#
#   📑 Section: Conclusion
#      Chunks in this section: 4
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-25-Conclusion
#        Metadata: {'section_category': 'Conclusion', 'chunk_number': 25, 'page_number': 8, 'paper_id': 4}
#        Page Number: 8
#        Chunk Number: 25
#        Text Preview: VII. CONCLUSION AND FUTURE WORK In this study, we extensively evaluated three prominent IoT middleware platforms, OM2M, ACME, and Mobius, with a focus...
#        Text Length: 1493 characters
#
#      Chunk 2:
#        ID: paper-1-26-Conclusion
#        Metadata: {'page_number': 8, 'chunk_number': 26, 'section_category': 'Conclusion', 'paper_id': 4}
#        Page Number: 8
#        Chunk Number: 26
#        Text Preview: avenue for enhancing responsiveness and reliability. REFERENCES [1] S. Pal, V. G. Diaz, and D.-N. Le, “Aws iot core,” 2022. [Online]. Available: https...
#        Text Length: 1618 characters
#
#      Chunk 3:
#        ID: paper-1-27-Conclusion
#        Metadata: {'paper_id': 4, 'section_category': 'Conclusion', 'chunk_number': 27, 'page_number': 8}
#        Page Number: 8
#        Chunk Number: 27
#        Text Preview: 2023. [Online]. Available: https://nodejs.org/en [14] J. Yun, I.-Y. Ahn, S. Choi, and J. Kim, “Tteo (things talk to each other): Programming smart spa...
#        Text Length: 1300 characters
#
#      Chunk 4:
#        ID: paper-1-28-Conclusion
#        Metadata: {'paper_id': 4, 'page_number': 8, 'section_category': 'Conclusion', 'chunk_number': 28}
#        Page Number: 8
#        Chunk Number: 28
#        Text Preview: [21] S. Mante, S. S. S. Vaddhiparthy, M. Ruthwik, D. Gangadharan, A. M. Hussain, and A. Vattem, “A multi layer data platform architecture for smart ci...
#        Text Length: 640 characters
#
#
# ================================================================================
# 📄 PAPER: 5
#    Total Chunks: 12
# ================================================================================
#
#   📑 Section: Problem Description
#      Chunks in this section: 2
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-4-Problem_Description
#        Metadata: {'section_category': 'Problem Description', 'paper_id': 5, 'page_number': 2, 'chunk_number': 4}
#        Page Number: 2
#        Chunk Number: 4
#        Text Preview: III. PROBLEM DESCRIPTION When data exhibits drift and is used for Natural Language Processing (NLP) applications, several issues can arise, im- pactin...
#        Text Length: 1413 characters
#
#      Chunk 2:
#        ID: paper-1-5-Problem_Description
#        Metadata: {'page_number': 2, 'section_category': 'Problem Description', 'paper_id': 5, 'chunk_number': 5}
#        Page Number: 2
#        Chunk Number: 5
#        Text Preview: that models remain robust and reliable over time....
#        Text Length: 49 characters
#
#   📑 Section: Methodology
#      Chunks in this section: 6
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-6-Methodology
#        Metadata: {'paper_id': 5, 'section_category': 'Methodology', 'chunk_number': 6, 'page_number': 2}
#        Page Number: 2
#        Chunk Number: 6
#        Text Preview: IV. METHODOLOGY Identifying data drift is a crucial aspect of maintaining the performance and reliability of machine learning models, including those ...
#        Text Length: 1391 characters
#
#      Chunk 2:
#        ID: paper-1-7-Methodology
#        Metadata: {'section_category': 'Methodology', 'paper_id': 5, 'chunk_number': 7, 'page_number': 2}
#        Page Number: 2
#        Chunk Number: 7
#        Text Preview: two group of text spread in a fixed time period is calculated. - The formula for the KS statistic is given by: D = max |F1(x) −F2(x)| - F1(x) and F2(x...
#        Text Length: 1280 characters
#
#      Chunk 3:
#        ID: paper-1-8-Methodology
#        Metadata: {'section_category': 'Methodology', 'paper_id': 5, 'page_number': 2, 'chunk_number': 8}
#        Page Number: 2
#        Chunk Number: 8
#        Text Preview: up discussion [15] and Topical chat [16]. The first step of our experiment involved preprocessing the conversation data to extract relevant informatio...
#        Text Length: 1305 characters
#
#      Chunk 4:
#        ID: paper-1-9-Methodology
#        Metadata: {'paper_id': 5, 'section_category': 'Methodology', 'chunk_number': 9, 'page_number': 2}
#        Page Number: 2
#        Chunk Number: 9
#        Text Preview: in the conversation dynamics with higher temporal resolution was captured. Fig. 2 presents the p-value results of this hourly analysis, highlighting t...
#        Text Length: 1342 characters
#
#      Chunk 5:
#        ID: paper-1-10-Methodology
#        Metadata: {'page_number': 2, 'paper_id': 5, 'chunk_number': 10, 'section_category': 'Methodology'}
#        Page Number: 2
#        Chunk Number: 10
#        Text Preview: duration within specific topical contexts. Upon preprocessing the Topical dataset to extract times- tamps and conversation text, similar to the previo...
#        Text Length: 1401 characters
#
#      Chunk 6:
#        ID: paper-1-11-Methodology
#        Metadata: {'section_category': 'Methodology', 'page_number': 2, 'chunk_number': 11, 'paper_id': 5}
#        Page Number: 2
#        Chunk Number: 11
#        Text Preview: online conversations, particularly in scenarios involving large and diverse collections of discussions across different topical domains. Fig. 1. Data ...
#        Text Length: 1177 characters
#
#   📑 Section: Conclusion
#      Chunks in this section: 4
#      ----------------------------------------------------------------------
#
#      Chunk 1:
#        ID: paper-1-12-Conclusion
#        Metadata: {'page_number': 4, 'section_category': 'Conclusion', 'paper_id': 5, 'chunk_number': 12}
#        Page Number: 4
#        Chunk Number: 12
#        Text Preview: VI. CONCLUSION In conclusion, this work has delved into the critical realm of identifying data drift in conversational datasets over time. Through a c...
#        Text Length: 1378 characters
#
#      Chunk 2:
#        ID: paper-1-13-Conclusion
#        Metadata: {'chunk_number': 13, 'page_number': 4, 'section_category': 'Conclusion', 'paper_id': 5}
#        Page Number: 4
#        Chunk Number: 13
#        Text Preview: Masegosa, A. M. Mart´ınez, D. Ramos-L´opez, H. Langseth, T. D. Nielsen, and A. Salmer´on, “Analyzing concept drift: A case study in the financial sect...
#        Text Length: 1300 characters
#
#      Chunk 3:
#        ID: paper-1-14-Conclusion
#        Metadata: {'section_category': 'Conclusion', 'page_number': 4, 'chunk_number': 14, 'paper_id': 5}
#        Page Number: 4
#        Chunk Number: 14
#        Text Preview: Brazilian Symposium on Artificial Intelligence, Sao Luis, Maranhao, Brazil, September 29-Ocotber 1, 2004. Proceedings 17. Springer, 2004, pp. 286–295....
#        Text Length: 1508 characters
#
#      Chunk 4:
#        ID: paper-1-15-Conclusion
#        Metadata: {'section_category': 'Conclusion', 'chunk_number': 15, 'page_number': 4, 'paper_id': 5}
#        Page Number: 4
#        Chunk Number: 15
#        Text Preview: June 24-28, 2024, IIT - Mandi, Kamand, India Authorized licensed use limited to: INTERNATIONAL INSTITUTE OF INFORMATION TECHNOLOGY. Downloaded on Octo...
#        Text Length: 215 characters
#
#
# ================================================================================
# 📊 SUMMARY STATISTICS
# ================================================================================
# Total Papers: 5
#
# 1:
#   - Background: 5 chunks
#   - Conclusion: 4 chunks
#   - Introduction: 3 chunks
#   - Key Features Of a Tool: 10 chunks
#   - Literature Review: 2 chunks
#
# 2:
#   - Acknowledgments: 4 chunks
#   - Basic Design Components: 13 chunks
#   - Conclusion: 1 chunks
#   - Implementation and Evaluation: 12 chunks
#   - Introduction: 7 chunks
#   - Related Work: 2 chunks
#   - Service Placement Module: 5 chunks
#   - System Overview: 3 chunks
#
# 3:
#   - Discussion: 6 chunks
#   - Evaluation: 3 chunks
#   - Software Development Life Cycles: 15 chunks
#
# 4:
#   - Conclusion: 4 chunks
#   - Discussion: 3 chunks
#   - Motivation: 2 chunks
#   - Related Work: 2 chunks
#   - Results: 4 chunks
#   - Study Design and Execution: 10 chunks
#
# 5:
#   - Conclusion: 4 chunks
#   - Methodology: 6 chunks
#   - Problem Description: 2 chunks
